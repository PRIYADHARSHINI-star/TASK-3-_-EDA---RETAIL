# %% [markdown]
# # #The Sparks Foundation

# %% [markdown]
# # #GRIPMAY21

# %% [markdown]
# # #Graduate Rotational Internship Program

# %% [markdown]
# # #DATA SCIENCE AND BUSINESS ANALYTICS:

# %% [markdown]
# # #Task 3: Exploratory Data Analysis - Retail

# %% [markdown]
# # #Author : R. Priyadharshini ( Coimbatore Institute of Technology )

# %% [markdown]
# # IMPORTING LIBRARIES:

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # SAMPLE SUPER STORE DATASET:

# %%
data = pd.read_excel('SampleSuperstore.xlsx',sheet_name='SampleSuperstore')
data.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
data.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# # DATA DESCRIPTION:

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# # FINDING MISSING VALUES:

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # SINCE DATA CONTAINS NON NULL VALUES,WE CAN PROCEED FURTHER

# %% [markdown]
# # CHECKING DUPLICATE IN DATASET AND DROPPING:

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS:

# %% [markdown]
# # 1. CORRELATION:

# %%
Data_corr = data.corr()

# %%
Data_corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(Data_corr,ax=ax,linewidths=.7,annot=True)

# %% [markdown]
# # 2. COVARIANCE:

# %%
Data_cov = data.cov()

# %%
Data_cov
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(Data_cov,ax=ax,linewidths=.7,annot=True)

# %%
col=['Postal Code']
df1=data.drop(columns=col,axis=1)

# %% [markdown]
# # 3. COUNTPLOT:  CATEGORIES

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.countplot(x ='Category', data = data, ax=ax)

# %% [markdown]
# # BAR CHART INTERPRETATION:

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category',data=data)
# Out:
# <BarContainer object of 9994 artists>

# %% [markdown]
# # STATE WISE COUNTPLOT:

# %%
print(data['State'].value_counts())
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=data['State'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # SUB CATEGORY WISE COUNTPLOT:

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=data['Sub-Category'])
plt.xticks(rotation=90)
plt.show()

# %%
data['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# # COUNTPLOT FOR SEGMENT:

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=data['Segment'])
plt.show()

# %% [markdown]
# # COUNTPLOT FOR SHIP MODE:

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=data['Ship Mode'])
plt.show()

# %% [markdown]
# # COUNT PLOT FOR REGION:

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=data['Region'])
plt.show()

# %% [markdown]
# # COUNTPLOT FOR QUANTITY:

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=data['Quantity'])
plt.show()

# %% [markdown]
# # PROFIT VS CATEGORY:

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=data['Category'], y=data['Profit'])

# %% [markdown]
# # PROFIT VS SUB-CATEGORY

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data['Sub-Category'], y=data['Profit'])

# %% [markdown]
# # PROFIT AND DISCOUNT LINE PLOT:

# %%
plt.figure(figsize = (10,4))
sns.lineplot('Discount', 'Profit', data = data, color = 'r', label= 'Discount')
plt.legend()

# %% [markdown]
# # STATE WISE CENTRAL TENDENCY FOR PROFIT:

# %%
data.groupby("State").Profit.agg(["sum","mean","min","max","count","median","std","var"])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76381.3871   38.171608  -325.5720  1906.4850   2001
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12607.8870  -25.625787 -2929.4845   874.9875    492
# ...

# %% [markdown]
# # RELATION BETWEEN SALES AND PROFIT:

# %%
plt.figure(figsize=(10,10))
plt.scatter(data.Sales,data.Profit)

# %% [markdown]
# # DISTRIBUTION PLOT FOT NUMERICAL FEATURE:

# %%
Numerical_Feature = ['Sales','Quantity','Discount','Profit']

# %%
for i in Numerical_Feature:
    plt.figure(figsize=(18, 10), facecolor='y')
    sns.distplot(data[i])
    plt.title('{} DISTRIBUTION'.format(i), fontsize=20)

# %% [markdown]
# # PAIR PLOT:

# %%
sns.pairplot(data)

# %% [markdown]
# # SUB-CATEGORY AND SALES:

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data['Sub-Category'], y=data['Sales'])

# %% [markdown]
# # CATEGORY AND SALES

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data['Category'], y=data['Sales'])

# %% [markdown]
# # HISTOGRAM PLOT FOR DATASET:

# %%
data.hist(figsize=(20,15))
plt.show()

# %%
#lets compare each categories Sales, Profits, Quantity and discount per order by plotting bar graphs

# %%
fig,ax=plt.subplots(2,2,figsize=(18,8),sharex=True)
labels=data.groupby(by='Category').agg('sum').index
sns.barplot(x=data.groupby(by='Category').agg('sum').index,y=data.groupby(by='Category').agg('sum').Profit,order=labels,ax=ax[0][0])
sns.barplot(x=data.groupby(by='Category').agg('sum').index,y=data.groupby(by='Category').agg('sum').Quantity,order=labels,ax=ax[1][0])
sns.barplot(x=data.groupby(by='Category').agg('sum').index,y=data.groupby(by='Category').agg('sum').Sales,order=labels,ax=ax[0][1])
sns.barplot(x=data.groupby(by='Category').agg('sum').index,y=data.groupby(by='Category').agg('mean').Discount,order=labels,ax=ax[1][1])
plt.sca(ax[1][1])
plt.ylabel('Average discount per order')
plt.xticks(rotation=60)
plt.sca(ax[1][0])
plt.xticks(rotation=60)
plt.show()

# %%
#lets compare each sub-categories Sales, Profits, Quantity and discount per order by plotting bar graphs

# %%
fig,ax=plt.subplots(2,2,figsize=(18,8),sharex=True)
labels=data.groupby(by='Sub-Category').agg('sum').index
sns.barplot(x=data.groupby(by='Sub-Category').agg('sum').index,y=data.groupby(by='Sub-Category').agg('sum').Profit,order=labels,ax=ax[0][0])
sns.barplot(x=data.groupby(by='Sub-Category').agg('sum').index,y=data.groupby(by='Sub-Category').agg('sum').Quantity,order=labels,ax=ax[1][0])
sns.barplot(x=data.groupby(by='Sub-Category').agg('sum').index,y=data.groupby(by='Sub-Category').agg('sum').Sales,order=labels,ax=ax[0][1])
sns.barplot(x=data.groupby(by='Sub-Category').agg('sum').index,y=data.groupby(by='Sub-Category').agg('mean').Discount,order=labels,ax=ax[1][1])
plt.sca(ax[1][1])
plt.ylabel('Average discount per order')
plt.xticks(rotation=60)
plt.sca(ax[1][0])
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# # profit and loss Percentage for each and every sub-category:

# %%
profit=data[data.Profit>0]
loss=data[data.Profit<0]

plt.pie(profit.groupby('Sub-Category').agg('sum').Profit,radius=3.12,labels=profit.groupby('Sub-Category').agg('sum').index,autopct='%1.2f%%')
plt.title('PROFIT',fontsize=20,pad=100,loc='center')
plt.show()

plt.pie(np.abs(loss.groupby('Sub-Category').agg('sum').Profit),radius=3.12,labels=loss.groupby('Sub-Category').agg('sum').index,autopct='%1.2f%%')
plt.title('LOSS',fontsize=20,pad=100,loc='center')
plt.show()

# %% [markdown]
# # Profit and Loss Percentage for Category:

# %%
profit=data[data.Profit>0]
loss=data[data.Profit<0]

plt.pie(profit.groupby('Category').agg('sum').Profit,radius=3.12,labels=profit.groupby('Category').agg('sum').index,autopct='%1.2f%%')
plt.title('PROFIT',fontsize=20,pad=100,loc='center')
plt.show()

plt.pie(np.abs(loss.groupby('Category').agg('sum').Profit),radius=3.12,labels=loss.groupby('Category').agg('sum').index,autopct='%1.2f%%')
plt.title('LOSS',fontsize=20,pad=100,loc='center')
plt.show()

# %% [markdown]
# # DISCOUNT AND PROFIT COMPARISON:

# %%
data[['Discount','Profit']].plot(kind='hist', figsize=(12,6))
plt.title('Discount and Profit')
plt.show()

# %% [markdown]
# # SALES AND PROFIT COMPARISON:

# %%
data[['Sales','Profit']].plot(kind='line', figsize=(12,6))
plt.title('Sales ans Profit')
plt.show()

# %% [markdown]
# #                                           THANK YOU
